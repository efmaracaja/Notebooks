# %%
from IPython.display import display
from IPython.display import HTML

HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
#coding: latin-1
from sqlalchemy import create_engine
from sqlalchemy import MetaData
import pandas as pd
import datetime
from tqdm import tqdm
import os
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import math
import numpy as np
import seaborn as sns

# %%
db_uri = 'mysql+mysqldb://root:Sql52213!@localhost/mde'
engine = create_engine(db_uri)

# %%
df_REF801 = pd.read_sql_table('ref-801', engine, index_col='Date')
df_REF801.index = pd.to_datetime(df_REF801.index, format='%Y-%m-%d %H:%M:%S')
df_REF801['Charge'] = df_REF801['Charge_Comp-A'] + df_REF801['Charge_Comp-B']

df_REF802 = pd.read_sql_table('ref-802', engine, index_col='Date')
df_REF802.index = pd.to_datetime(df_REF802.index, format='%Y-%m-%d %H:%M:%S')
df_REF802['Charge'] = df_REF802['Charge_Comp-A'] + df_REF802['Charge_Comp-B']

# %%
df_REF801['Saison'] = 'hiver'
df_REF801['Saison'][df_REF801.index > '2017-03-20'] = 'printemps'
df_REF801['Saison'][df_REF801.index > '2017-06-21'] = 'ete'
df_REF801['Saison'][df_REF801.index > '2017-09-22'] = 'automne'

df_REF802['Saison'] = 'hiver'
df_REF802['Saison'][df_REF802.index > '2017-03-20'] = 'printemps'
df_REF802['Saison'][df_REF802.index > '2017-06-21'] = 'ete'
df_REF802['Saison'][df_REF802.index > '2017-09-22'] = 'automne'
# Out:
# /Users/user/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/user/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/user/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
ax = sns.violinplot(x='Saison',
                    y='Charge',
                   data=df_REF801[df_REF801['Charge'] > 0.],
                   palette='muted')
plt.show()

# %%
ax = sns.violinplot(x='Saison',
                    y='Charge',
                   data=df_REF802[df_REF802['Charge'] > 0.],
                   palette='muted')
plt.show()

# %%
ax = sns.violinplot(x=['Deb_Cond', 'Deb_Evap'],
                    y=['Deb_Cond', 'Deb_Evap'],
                    data=df_REF801[df_REF801['Charge'] > 0.],
                   palette='muted')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2474ea17bfd0> in <module>()
#       2                     y=['Deb_Cond', 'Deb_Evap'],
#       3                     data=df_REF801[df_REF801['Charge'] > 0.],
# ----> 4                    palette='muted')
#       5 plt.show()
#
# /Users/user/anaconda2/lib/python2.7/site-packages/seaborn/categorical.pyc in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2362                              bw, cut, scale, scale_hue, gridsize,
#    2363                              width, inner, split, dodge, orient, linewidth,
# -> 2364                              color, palette, saturation)
#    2365
#    2366     if ax is None:
#
# ...
